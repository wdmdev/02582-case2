# %% [markdown]
# # Hollywood Face Distances

# %%
import os
import pandas as pd

# %%
face_folder = 'hollywood_faces_distances.csv'
face_distances = os.path.join('..', 'reports', face_folder)
df = pd.read_csv(face_distances)
cols = df.columns.tolist()
cols[0] = ''
df.columns = cols
df.set_index(df.columns[0])
# Out:
#                 Anna Hathaway  Chris Rock  Cillian Murphy  Mads Mikkelsen  \
#
# Anna Hathaway        0.000000   97.265240       79.264347       37.424550
# Chris Rock          97.265240    0.000000       79.847239       91.395558
# Cillian Murphy      79.264347   79.847239        0.000000       87.693367
# Mads Mikkelsen      37.424550   91.395558       87.693367        0.000000
# Steven Yuen         63.294031   82.112921       60.040605       72.954151
# Susan Cheng         96.081288   80.032280       65.640831       98.172367
# Will Smith          89.748212   97.362846       98.989983       79.520435
# Zoe Kravitz         75.879705   71.554292       47.014353       74.310203
#
#                 Steven Yuen  Susan Cheng  Will Smith  Zoe Kravitz  \
#
# Anna Hathaway     63.294031    96.081288   89.748212    75.879705
# Chris Rock        82.112921    80.032280   97.362846    71.554292
# Cillian Murphy    60.040605    65.640831   98.989983    47.014353
# ...
